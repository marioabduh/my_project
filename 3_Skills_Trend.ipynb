# %% [markdown]
# # How are in-demand skills trending for Data Scientists?
# ### Methodology
# 1. Aggregate skill counts monthly
# 2. Re-analyze based on percentage of total jobs
# 3. Plot the monthly skill demand

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import seaborn as sns
import ast

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x) # Use ast.literal_eval to convert a list with a string type into a list type

# %%
df['job_title_short'].unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df_DS_US = df[(df['job_title_short'] == 'Data Scientist') & (df['job_country'] == 'United States')].copy()

# %%
df_DS_US['job_posted_month_no'] = df_DS_US['job_posted_date'].dt.month

# %%
df_DS_US_explode = df_DS_US.explode('job_skills')

# %%
df_DS_US_pivot = df_DS_US_explode.pivot_table(index='job_posted_month_no', columns='job_skills', aggfunc='size', fill_value=0)
df_DS_US_pivot.loc['Total'] = df_DS_US_pivot.sum()
df_DS_US_pivot = df_DS_US_pivot[df_DS_US_pivot.loc['Total'].sort_values(ascending=False).index]
df_DS_US_pivot = df_DS_US_pivot.drop('Total')

# %%
df_DS_US_pivot
# Out:
# job_skills           python   sql     r   sas  tableau   aws  spark  java  \
# job_posted_month_no
# 1                      5243  3770  3362  1700     1630  1364   1356   916
# 2                      3718  2670  2334  1144     1268   854    895   645
# 3                      3394  2426  2189  1144     1126   848    787   575
# 4                      3622  2463  2181  1204     1213   882    823   622
# 5                      3232  2293  2016  1150     1174   797    774   629
# 6                      3431  2442  2107  1158     1135   818    822   586
# 7                      3541  2479  2210  1106     1223   860    802   581
# 8                      4566  3324  2896  1598     1520  1076   1075   767
# 9                      3112  2155  1791  1158      921   697    740   534
# 10                     3291  2267  1877  1110     1007   806    682   593
# 11                     2852  2015  1684  1040      861   676    611   500
# ...

# %%
DS_total = df_DS_US.groupby('job_posted_month_no').size()

# %%
df_DS_US_pct = df_DS_US_pivot.div(DS_total/100, axis=0)

# %%
df_DS_US_pct = df_DS_US_pct.reset_index()
df_DS_US_pct['job_posted_month'] = df_DS_US_pct['job_posted_month_no'].apply(lambda x: pd.to_datetime(x, format='%m').strftime('%b'))
df_DS_US_pct = df_DS_US_pct.set_index('job_posted_month')
df_DS_US_pct = df_DS_US_pct.drop(columns='job_posted_month_no')

df_DS_US_pct
# Out:
# job_skills           python        sql          r        sas    tableau  \
# job_posted_month
# Jan               75.820680  54.519161  48.618944  24.584237  23.571945
# Feb               75.020178  53.874092  47.094431  23.083132  25.585149
# Mar               71.019042  50.763758  45.804562  23.938062  23.561415
# Apr               74.419560  50.606123  44.811999  24.738032  24.922950
# May               73.840530  52.387480  46.058944  26.273703  26.822024
# Jun               73.864370  52.572659  45.360603  24.930032  24.434876
# Jul               72.621001  50.840853  45.324036  22.682527  25.082034
# Aug               72.269706  52.611586  45.837290  25.292814  24.058246
# Sep               68.126095  47.176007  39.207531  25.350263  20.161996
# Oct               67.410897  46.435887  38.447358  22.736583  20.626792
# Nov               68.311377  48.263473  40.335329  24.910180  20.622754
# Dec               68.461982  49.827189  39.602535  23.847926  22.494240
#
# ...

# %%
df_plot = df_DS_US_pct.iloc[:, :5]
sns.set_theme(style='ticks')
sns.lineplot(df_plot, dashes=False, palette='tab10')
sns.despine()

plt.title('Trenidng Top Skills for Data Scientists in the US')
plt.ylabel('Likelihood in Job Posting')
plt.xlabel('2023')
plt.legend().remove()
plt.tight_layout()

ax= plt.gca()
ax.yaxis.set_major_formatter(PercentFormatter(decimals=0))

for i in range(5):
    plt.text(11.2, df_plot.iloc[-1, i], df_plot.columns[i])
